# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,10,25)

# %%
plt.plot(x, np.cos(1 *x))
plt.plot(x, np.cos(0.7* x))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
